# %%
import pandas as pd 
import glob
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from copy import copy
from scipy import stats
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go

# %%
path = 'stocks _data'
all_files=glob.glob(path+"/*.csv")

# %%
all_files
# Out:
# ['stocks _data\\A.csv',
#  'stocks _data\\AAALY.csv',
#  'stocks _data\\AAC.csv',
#  'stocks _data\\AACAY.csv',
#  'stocks _data\\AAL.csv',
#  'stocks _data\\AAME.csv',
#  'stocks _data\\AAOI.csv',
#  'stocks _data\\AAON.csv',
#  'stocks _data\\AAP.csv',
#  'stocks _data\\AAPL.csv',
#  'stocks _data\\AAT.csv',
#  'stocks _data\\AAVL.csv',
#  'stocks _data\\AAWW.csv',
#  'stocks _data\\AB.csv',
#  'stocks _data\\ABBV.csv',
#  'stocks _data\\ABC.csv',
#  'stocks _data\\ABCB.csv',
#  'stocks _data\\ABCD.csv',
#  'stocks _data\\ABCO.csv',
#  'stocks _data\\ABG.csv',
#  'stocks _data\\ABGOY.csv',
#  'stocks _data\\ABIO.csv',
#  'stocks _data\\ABLT.csv',
#  'stocks _data\\ABM.csv',
#  'stocks _data\\ABMD.csv',
#  'stocks _data\\ABR.csv',
#  'stocks _data\\ABT.csv',
#  'stocks _data\\ABTZY.csv',
#  'stocks _data\\ACAD.csv',
#  'stocks _data\\ACC.csv',
#  'stocks _data\\ACCYY.csv',
#  'stocks _data\\ACDVF.csv',
#  'stocks _data\\ACET.csv',
#  'stocks _data\\ACFC.csv',
#  'stocks _data\\ACFL.csv',
#  'stocks _data\\ACFN.csv',
#  'stocks _data\\ACG.csv',
#  'stocks _data\\ACGBY.csv',
#  'stocks _data\\ACGL.csv',
#  'stocks _data\\ACH.csv',
#  'stocks _data\\ACHC.csv',
#  'stocks _data\\ACHN.csv',
#  'stocks _data\\ACIW.csv',
#  'stocks _data\\ACLS.csv',
#  'stocks _data\\ACN.csv',
#  'stocks _data\\ACNB.csv',
#  'stocks _data\\ACOR.csv',
#  'stocks _data\\ACP.csv',
#  'stocks _data\\ACRE.csv',
#  'stocks _data\\ACRX.csv',
#  'stocks _data\\ACST.csv',
#  'stocks _data\\ACTA.csv',
#  'stocks _data\\ACTG.csv',
#  'stocks _data\\ACUR.csv',
#  'stocks _data\\ACXIF.csv',
#  'stocks _data\\ADBE.csv',
#  'stocks _data\\ADC.csv',
#  'stocks _data\\ADDYY.csv',
#  'stocks _data\\ADERY.csv',
#  'stocks _data\\ADES.csv',
#  'stocks _data\\ADI.csv',
#  'stocks _data\\ADM.csv',
#  'stocks _data\\ADMA.csv',
#  'stocks _data\\ADMP.csv',
#  'stocks _data\\ADMS.csv',
#  'stocks _data\\ADP.csv',
#  'stocks _data\\ADPT.csv',
#  'stocks _data\\ADS.csv',
#  'stocks _data\\ADSK.csv',
#  'stocks _data\\ADTN.csv',
#  'stocks _data\\ADUS.csv',
#  'stocks _data\\ADXS.csv',
#  'stocks _data\\AEE.csv',
#  'stocks _data\\AEHR.csv',
#  'stocks _data\\AEIS.csv',
#  'stocks _data\\AEL.csv',
#  'stocks _data\\AELTF.csv',
#  'stocks _data\\AEM.csv',
#  'stocks _data\\AEO.csv',
#  'stocks _data\\AEP.csv',
#  'stocks _data\\AER.csv',
#  'stocks _data\\AERI.csv',
#  'stocks _data\\AET.csv',
#  'stocks _data\\AEY.csv',
#  'stocks _data\\AEZS.csv',
#  'stocks _data\\AFAM.csv',
#  'stocks _data\\AFB.csv',
#  'stocks _data\\AFCB.csv',
#  'stocks _data\\AFG.csv',
#  'stocks _data\\AFLYY.csv',
#  'stocks _data\\AFMD.csv',
#  'stocks _data\\AFSI.csv',
#  'stocks _data\\AFT.csv',
#  'stocks _data\\AG.csv',
#  'stocks _data\\AGD.csv',
#  'stocks _data\\AGEN.csv',
#  'stocks _data\\AGI.csv',
#  'stocks _data\\AGIO.csv',
#  'stocks _data\\AGM.csv',
#  'stocks _data\\AGNC.csv',
#  'stocks _data\\AGO.csv',
#  'stocks _data\\AGPYY.csv',
#  'stocks _data\\AGRO.csv',
#  'stocks _data\\AGRUF.csv',
#  'stocks _data\\AGRX.csv',
#  'stocks _data\\AGTC.csv',
#  'stocks _data\\AGYS.csv',
#  'stocks _data\\AGZNF.csv',
#  'stocks _data\\AHCHY.csv',
#  'stocks _data\\AHGP.csv',
#  'stocks _data\\AHH.csv',
#  'stocks _data\\AHKSY.csv',
#  'stocks _data\\AHL.csv',
#  'stocks _data\\AHODF.csv',
#  'stocks _data\\AHPI.csv',
#  'stocks _data\\AHT.csv',
#  'stocks _data\\AI.csv',
#  'stocks _data\\AIAGF.csv',
#  'stocks _data\\AIF.csv',
#  'stocks _data\\AIG.csv',
#  'stocks _data\\AIMC.csv',
#  'stocks _data\\AIN.csv',
#  'stocks _data\\AINV.csv',
#  'stocks _data\\AIPUY.csv',
#  'stocks _data\\AIQ.csv',
#  'stocks _data\\AIRI.csv',
#  'stocks _data\\AIRT.csv',
#  'stocks _data\\AIT.csv',
#  'stocks _data\\AIV.csv',
#  'stocks _data\\AIZ.csv',
#  'stocks _data\\AJG.csv',
#  'stocks _data\\AJINY.csv',
#  'stocks _data\\AJISF.csv',
#  'stocks _data\\AKAM.csv',
#  'stocks _data\\AKBA.csv',
#  'stocks _data\\AKBTY.csv',
#  'stocks _data\\AKO-A.csv',
#  'stocks _data\\AKR.csv',
#  'stocks _data\\AKZOY.csv',
#  'stocks _data\\ALB.csv',
#  'stocks _data\\ALBKY.csv',
#  'stocks _data\\ALCO.csv',
#  'stocks _data\\ALDX.csv',
#  'stocks _data\\ALEX.csv',
#  'stocks _data\\ALGN.csv',
#  'stocks _data\\ALGT.csv',
#  'stocks _data\\ALIM.csv',
#  'stocks _data\\ALK.csv',
#  'stocks _data\\ALKS.csv',
#  'stocks _data\\ALL.csv',
#  'stocks _data\\ALLE.csv',
#  'stocks _data\\ALLT.csv',
#  'stocks _data\\ALLY.csv',
#  'stocks _data\\ALNY.csv',
#  'stocks _data\\ALOG.csv',
#  'stocks _data\\ALPMY.csv',
#  'stocks _data\\ALSMY.csv',
#  'stocks _data\\ALSN.csv',
#  'stocks _data\\ALTR.csv',
#  'stocks _data\\ALV.csv',
#  'stocks _data\\AMADY.csv',
#  'stocks _data\\AMAT.csv',
#  'stocks _data\\AMBA.csv',
#  'stocks _data\\AMBC.csv',
#  'stocks _data\\AMBZ.csv',
#  'stocks _data\\AMC.csv',
#  'stocks _data\\AMCF.csv',
#  'stocks _data\\AMCX.csv',
#  'stocks _data\\AMD.csv',
#  'stocks _data\\AME.csv',
#  'stocks _data\\AMED.csv',
#  'stocks _data\\AMG.csv',
#  'stocks _data\\AMGN.csv',
#  'stocks _data\\AMH.csv',
#  'stocks _data\\AMIVF.csv',
#  'stocks _data\\AMKBY.csv',
#  'stocks _data\\AMKR.csv',
#  'stocks _data\\AMNB.csv',
#  'stocks _data\\AMOT.csv',
#  'stocks _data\\AMP.csv',
#  'stocks _data\\AMPH.csv',
#  'stocks _data\\AMRN.csv',
#  'stocks _data\\AMRS.csv',
#  'stocks _data\\AMSC.csv',
#  'stocks _data\\AMSWA.csv',
#  'stocks _data\\AMT.csv',
#  'stocks _data\\AMTX.csv',
#  'stocks _data\\AMWD.csv',
#  'stocks _data\\AMX.csv',
#  'stocks _data\\AMZN.csv',
#  'stocks _data\\AN.csv',
#  'stocks _data\\ANAC.csv',
#  'stocks _data\\ANAT.csv',
#  'stocks _data\\ANCB.csv',
#  'stocks _data\\ANCX.csv',
#  'stocks _data\\ANDE.csv',
#  'stocks _data\\ANET.csv',
#  'stocks _data\\ANF.csv',
#  'stocks _data\\ANGI.csv',
#  'stocks _data\\ANGO.csv',
#  'stocks _data\\ANIK.csv',
#  'stocks _data\\ANIP.csv',
#  'stocks _data\\ANR.csv',
#  'stocks _data\\ANTH.csv',
#  'stocks _data\\ANTM.csv',
#  'stocks _data\\ANY.csv',
#  'stocks _data\\AOD.csv',
#  'stocks _data\\AON.csv',
#  'stocks _data\\AOS.csv',
#  'stocks _data\\AOSL.csv',
#  'stocks _data\\APA.csv',
#  'stocks _data\\APAJF.csv',
#  'stocks _data\\APAM.csv',
#  'stocks _data\\APB.csv',
#  'stocks _data\\APD.csv',
#  'stocks _data\\APDN.csv',
#  'stocks _data\\APEI.csv',
#  'stocks _data\\APEMY.csv',
#  'stocks _data\\APH.csv',
#  'stocks _data\\APL.csv',
#  'stocks _data\\APOG.csv',
#  'stocks _data\\APTO.csv',
#  'stocks _data\\APWC.csv',
#  'stocks _data\\AR.csv',
#  'stocks _data\\ARAH.csv',
#  'stocks _data\\ARAY.csv',
#  'stocks _data\\ARC.csv',
#  'stocks _data\\ARCB.csv',
#  'stocks _data\\ARCC.csv',
#  'stocks _data\\ARCO.csv',
#  'stocks _data\\ARCW.csv',
#  'stocks _data\\ARDC.csv',
#  'stocks _data\\ARDX.csv',
#  'stocks _data\\ARE.csv',
#  'stocks _data\\ARHVF.csv',
#  'stocks _data\\ARI.csv',
#  'stocks _data\\ARII.csv',
#  'stocks _data\\ARIS.csv',
#  'stocks _data\\ARKAY.csv',
#  'stocks _data\\ARKR.csv',
#  'stocks _data\\ARL.csv',
#  'stocks _data\\ARLP.csv',
#  'stocks _data\\ARMK.csv',
#  'stocks _data\\ARNA.csv',
#  'stocks _data\\AROW.csv',
#  'stocks _data\\ARR.csv',
#  'stocks _data\\ARRY.csv',
#  'stocks _data\\ARTNA.csv',
#  'stocks _data\\ARW.csv',
#  'stocks _data\\ASA.csv',
#  'stocks _data\\ASB.csv',
#  'stocks _data\\ASBFF.csv',
#  'stocks _data\\ASBRF.csv',
#  'stocks _data\\ASC.csv',
#  'stocks _data\\ASEKY.csv',
#  'stocks _data\\ASGLY.csv',
#  'stocks _data\\ASGN.csv',
#  'stocks _data\\ASHTF.csv',
#  'stocks _data\\ASMB.csv',
#  'stocks _data\\ASML.csv',
#  'stocks _data\\ASPN.csv',
#  'stocks _data\\ASPS.csv',
#  'stocks _data\\ASR.csv',
#  'stocks _data\\ASRV.csv',
#  'stocks _data\\ASTC.csv',
#  'stocks _data\\ASTE.csv',
#  'stocks _data\\ASTI.csv',
#  'stocks _data\\ASUR.csv',
#  'stocks _data\\ASX.csv',
#  'stocks _data\\ASYS.csv',
#  'stocks _data\\ATAI.csv',
#  'stocks _data\\ATASY.csv',
#  'stocks _data\\ATAX.csv',
#  'stocks _data\\ATEC.csv',
#  'stocks _data\\ATEN.csv',
#  'stocks _data\\ATHN.csv',
#  'stocks _data\\ATHX.csv',
#  'stocks _data\\ATI.csv',
#  'stocks _data\\ATLC.csv',
#  'stocks _data\\ATLO.csv',
#  'stocks _data\\ATNM.csv',
#  'stocks _data\\ATNNF.csv',
#  'stocks _data\\ATO.csv',
#  'stocks _data\\ATONF.csv',
#  'stocks _data\\ATOS.csv',
#  'stocks _data\\ATRA.csv',
#  'stocks _data\\ATRC.csv',
#  'stocks _data\\ATRO.csv',
#  'stocks _data\\ATRS.csv',
#  'stocks _data\\ATSG.csv',
#  'stocks _data\\ATVI.csv',
#  'stocks _data\\ATW.csv',
#  'stocks _data\\AU.csv',
#  'stocks _data\\AUBN.csv',
#  'stocks _data\\AUDC.csv',
#  'stocks _data\\AUNB.csv',
#  'stocks _data\\AUPH.csv',
#  'stocks _data\\AUTR.csv',
#  'stocks _data\\AVAV.csv',
#  'stocks _data\\AVB.csv',
#  'stocks _data\\AVD.csv',
#  'stocks _data\\AVEO.csv',
#  'stocks _data\\AVG.csv',
#  'stocks _data\\AVGO.csv',
#  'stocks _data\\AVHI.csv',
#  'stocks _data\\AVID.csv',
#  'stocks _data\\AVK.csv',
#  'stocks _data\\AVNW.csv',
#  'stocks _data\\AVT.csv',
#  'stocks _data\\AVY.csv',
#  'stocks _data\\AWAY.csv',
#  'stocks _data\\AWF.csv',
#  'stocks _data\\AWH.csv',
#  'stocks _data\\AWK.csv',
#  'stocks _data\\AWR.csv',
#  'stocks _data\\AWRE.csv',
#  'stocks _data\\AXAS.csv',
#  'stocks _data\\AXDX.csv',
#  'stocks _data\\AXGN.csv',
#  'stocks _data\\AXL.csv',
#  'stocks _data\\AXP.csv',
#  'stocks _data\\AXTA.csv',
#  'stocks _data\\AXTI.csv',
#  'stocks _data\\AXXTF.csv',
#  'stocks _data\\AZN.csv',
#  'stocks _data\\AZO.csv',
#  'stocks _data\\AZPN.csv',
#  'stocks _data\\BA.csv',
#  'stocks _data\\BAC.csv',
#  'stocks _data\\BAESY.csv',
#  'stocks _data\\BAH.csv',
#  'stocks _data\\BAK.csv',
#  'stocks _data\\BALT.csv',
#  'stocks _data\\BAM.csv',
#  'stocks _data\\BANF.csv',
#  'stocks _data\\BANGN.csv',
#  'stocks _data\\BANR.csv',
#  'stocks _data\\BANX.csv',
#  'stocks _data\\BAP.csv',
#  'stocks _data\\BARK.csv',
#  'stocks _data\\BASFY.csv',
#  'stocks _data\\BAX.csv',
#  'stocks _data\\BBBY.csv',
#  'stocks _data\\BBD.csv',
#  'stocks _data\\BBGI.csv',
#  'stocks _data\\BBL.csv',
#  'stocks _data\\BBOX.csv',
#  'stocks _data\\BBRG.csv',
#  'stocks _data\\BBRYF.csv',
#  'stocks _data\\BBSI.csv',
#  'stocks _data\\BBVA.csv',
#  'stocks _data\\BBY.csv',
#  'stocks _data\\BCAUF.csv',
#  'stocks _data\\BCBHF.csv',
#  'stocks _data\\BCBP.csv',
#  'stocks _data\\BCC.csv',
#  'stocks _data\\BCEI.csv',
#  'stocks _data\\BCH.csv',
#  'stocks _data\\BCHHF.csv',
#  'stocks _data\\BCKIY.csv',
#  'stocks _data\\BCLI.csv',
#  'stocks _data\\BCMXY.csv',
#  'stocks _data\\BCOR.csv',
#  'stocks _data\\BCOV.csv',
#  'stocks _data\\BCPC.csv',
#  'stocks _data\\BCRX.csv',
#  'stocks _data\\BCS.csv',
#  'stocks _data\\BCX.csv',
#  'stocks _data\\BDCZ.csv',
#  'stocks _data\\BDJ.csv',
#  'stocks _data\\BDMS.csv',
#  'stocks _data\\BDN.csv',
#  'stocks _data\\BDORY.csv',
#  'stocks _data\\BDOUY.csv',
#  'stocks _data\\BDRBF.csv',
#  'stocks _data\\BDSI.csv',
#  'stocks _data\\BDX.csv',
#  'stocks _data\\BEAT.csv',
#  'stocks _data\\BEBE.csv',
#  'stocks _data\\BECN.csv',
#  'stocks _data\\BELFB.csv',
#  'stocks _data\\BEN.csv',
#  'stocks _data\\BEP.csv',
#  'stocks _data\\BERY.csv',
#  'stocks _data\\BF-A.csv',
#  'stocks _data\\BFAM.csv',
#  'stocks _data\\BFIN.csv',
#  'stocks _data\\BFK.csv',
#  'stocks _data\\BFZ.csv',
#  'stocks _data\\BG.csv',
#  'stocks _data\\BGAOY.csv',
#  'stocks _data\\BGB.csv',
#  'stocks _data\\BGC.csv',
#  'stocks _data\\BGCP.csv',
#  'stocks _data\\BGFV.csv',
#  'stocks _data\\BGMD.csv',
#  'stocks _data\\BGR.csv',
#  'stocks _data\\BGT.csv',
#  'stocks _data\\BGX.csv',
#  'stocks _data\\BH.csv',
#  'stocks _data\\BHE.csv',
#  'stocks _data\\BHI.csv',
#  'stocks _data\\BHK.csv',
#  'stocks _data\\BHL.csv',
#  'stocks _data\\BHLB.csv',
#  'stocks _data\\BHP.csv',
#  'stocks _data\\BIDU.csv',
#  'stocks _data\\BIF.csv',
#  'stocks _data\\BIIB.csv',
#  'stocks _data\\BIN.csv',
#  'stocks _data\\BIND.csv',
#  'stocks _data\\BIO.csv',
#  'stocks _data\\BIOC.csv',
#  'stocks _data\\BIP.csv',
#  'stocks _data\\BIRDF.csv',
#  'stocks _data\\BITRF.csv',
#  'stocks _data\\BJRI.csv',
#  'stocks _data\\BJZ.csv',
#  'stocks _data\\BK.csv',
#  'stocks _data\\BKCC.csv',
#  'stocks _data\\BKD.csv',
#  'stocks _data\\BKEP.csv',
#  'stocks _data\\BKHYY.csv',
#  'stocks _data\\BKN.csv',
#  'stocks _data\\BKNIY.csv',
#  'stocks _data\\BKQNY.csv',
#  'stocks _data\\BKRKY.csv',
#  'stocks _data\\BKRL.csv',
#  'stocks _data\\BKT.csv',
#  'stocks _data\\BKU.csv',
#  'stocks _data\\BKUT.csv',
#  'stocks _data\\BLCM.csv',
#  'stocks _data\\BLD.csv',
#  'stocks _data\\BLDP.csv',
#  'stocks _data\\BLDR.csv',
#  'stocks _data\\BLFS.csv',
#  'stocks _data\\BLH.csv',
#  'stocks _data\\BLIN.csv',
#  'stocks _data\\BLK.csv',
#  'stocks _data\\BLKB.csv',
#  'stocks _data\\BLMN.csv',
#  'stocks _data\\BLRX.csv',
#  'stocks _data\\BLSFF.csv',
#  'stocks _data\\BLUE.csv',
#  'stocks _data\\BLW.csv',
#  'stocks _data\\BLX.csv',
#  'stocks _data\\BMBLF.csv',
#  'stocks _data\\BME.csv',
#  'stocks _data\\BMO.csv',
#  'stocks _data\\BMRA.csv',
#  'stocks _data\\BMRC.csv',
#  'stocks _data\\BMRN.csv',
#  'stocks _data\\BMS.csv',
#  'stocks _data\\BMTC.csv',
#  'stocks _data\\BMY.csv',
#  'stocks _data\\BNCM.csv',
#  'stocks _data\\BNDSY.csv',
#  'stocks _data\\BNFT.csv',
#  'stocks _data\\BNGRF.csv',
#  'stocks _data\\BNJ.csv',
#  'stocks _data\\BNPQY.csv',
#  'stocks _data\\BNS.csv',
#  'stocks _data\\BNSO.csv',
#  'stocks _data\\BNTGY.csv',
#  'stocks _data\\BNY.csv',
#  'stocks _data\\BOH.csv',
#  'stocks _data\\BOKF.csv',
#  'stocks _data\\BOOT.csv',
#  'stocks _data\\BORT.csv',
#  'stocks _data\\BOSC.csv',
#  'stocks _data\\BOTJ.csv',
#  'stocks _data\\BOTRF.csv',
#  'stocks _data\\BOUYY.csv',
#  'stocks _data\\BPCGF.csv',
#  'stocks _data\\BPIRY.csv',
#  'stocks _data\\BPK.csv',
#  'stocks _data\\BPOP.csv',
#  'stocks _data\\BPT.csv',
#  'stocks _data\\BPXXY.csv',
#  'stocks _data\\BR.csv',
#  'stocks _data\\BRDCY.csv',
#  'stocks _data\\BRFH.csv',
#  'stocks _data\\BRFS.csv',
#  'stocks _data\\BRID.csv',
#  'stocks _data\\BRK-A.csv',
#  'stocks _data\\BRKL.csv',
#  'stocks _data\\BRKR.csv',
#  'stocks _data\\BRKS.csv',
#  'stocks _data\\BRO.csv',
#  'stocks _data\\BRP.csv',
#  'stocks _data\\BRTHY.csv',
#  'stocks _data\\BRX.csv',
#  'stocks _data\\BSAC.csv',
#  'stocks _data\\BSET.csv',
#  'stocks _data\\BSF.csv',
#  'stocks _data\\BSHI.csv',
#  'stocks _data\\BSL.csv',
#  'stocks _data\\BSPM.csv',
#  'stocks _data\\BSQR.csv',
#  'stocks _data\\BSRR.csv',
#  'stocks _data\\BST.csv',
#  'stocks _data\\BSTG.csv',
#  'stocks _data\\BSX.csv',
#  'stocks _data\\BTDPF.csv',
#  'stocks _data\\BTF.csv',
#  'stocks _data\\BTI.csv',
#  'stocks _data\\BTO.csv',
#  'stocks _data\\BTSGY.csv',
#  'stocks _data\\BTU.csv',
#  'stocks _data\\BTZ.csv',
#  'stocks _data\\BUD.csv',
#  'stocks _data\\BUI.csv',
#  'stocks _data\\BUR.csv',
#  'stocks _data\\BURL.csv',
#  'stocks _data\\BUSE.csv',
#  'stocks _data\\BV.csv',
#  'stocks _data\\BWA.csv',
#  'stocks _data\\BWEN.csv',
#  'stocks _data\\BWFG.csv',
#  'stocks _data\\BWG.csv',
#  'stocks _data\\BWMG.csv',
#  'stocks _data\\BWP.csv',
#  'stocks _data\\BXC.csv',
#  'stocks _data\\BXMT.csv',
#  'stocks _data\\BXMX.csv',
#  'stocks _data\\BXP.csv',
#  'stocks _data\\BXRBF.csv',
#  'stocks _data\\BXS.csv',
#  'stocks _data\\BYBK.csv',
#  'stocks _data\\BYCBF.csv',
#  'stocks _data\\BYFC.csv',
#  'stocks _data\\BYM.csv',
#  'stocks _data\\BZH.csv',
#  'stocks _data\\BZLFY.csv',
#  'stocks _data\\C-PK.csv',
#  'stocks _data\\C.csv',
#  'stocks _data\\CAA.csv',
#  'stocks _data\\CAAS.csv',
#  'stocks _data\\CABGY.csv',
#  'stocks _data\\CAC.csv',
#  'stocks _data\\CACC.csv',
#  'stocks _data\\CACH.csv',
#  'stocks _data\\CAF.csv',
#  'stocks _data\\CAG.csv',
#  'stocks _data\\CAH.csv',
#  'stocks _data\\CAI.csv',
#  'stocks _data\\CAIXY.csv',
#  'stocks _data\\CAKE.csv',
#  'stocks _data\\CALA.csv',
#  'stocks _data\\CALD.csv',
#  'stocks _data\\CALI.csv',
#  'stocks _data\\CALL.csv',
#  'stocks _data\\CAMP.csv',
#  'stocks _data\\CAMT.csv',
#  'stocks _data\\CAR.csv',
#  'stocks _data\\CARA.csv',
#  'stocks _data\\CARV.csv',
#  'stocks _data\\CASH.csv',
#  'stocks _data\\CASI.csv',
#  'stocks _data\\CASS.csv',
#  'stocks _data\\CASY.csv',
#  'stocks _data\\CAT.csv',
#  'stocks _data\\CATY.csv',
#  'stocks _data\\CAVM.csv',
#  'stocks _data\\CB.csv',
#  'stocks _data\\CBA.csv',
#  'stocks _data\\CBAN.csv',
#  'stocks _data\\CBAOF.csv',
#  'stocks _data\\CBAY.csv',
#  'stocks _data\\CBD.csv',
#  'stocks _data\\CBFC.csv',
#  'stocks _data\\CBFV.csv',
#  'stocks _data\\CBI.csv',
#  'stocks _data\\CBL.csv',
#  'stocks _data\\CBLUY.csv',
#  'stocks _data\\CBNK.csv',
#  'stocks _data\\CBOE.csv',
#  'stocks _data\\CBOF.csv',
#  'stocks _data\\CBRL.csv',
#  'stocks _data\\CBSH.csv',
#  'stocks _data\\CBU.csv',
#  'stocks _data\\CBUMF.csv',
#  'stocks _data\\CBX.csv',
#  'stocks _data\\CCBC.csv',
#  'stocks _data\\CCBG.csv',
#  'stocks _data\\CCF.csv',
#  'stocks _data\\CCGDF.csv',
#  'stocks _data\\CCGY.csv',
#  'stocks _data\\CCHGY.csv',
#  'stocks _data\\CCI.csv',
#  'stocks _data\\CCIH.csv',
#  'stocks _data\\CCK.csv',
#  'stocks _data\\CCLP.csv',
#  'stocks _data\\CCM.csv',
#  'stocks _data\\CCMP.csv',
#  'stocks _data\\CCNE.csv',
#  'stocks _data\\CCOHF.csv',
#  'stocks _data\\CCOI.csv',
#  'stocks _data\\CCRN.csv',
#  'stocks _data\\CCS.csv',
#  'stocks _data\\CCU.csv',
#  'stocks _data\\CCUR.csv',
#  'stocks _data\\CCXI.csv',
#  'stocks _data\\CCZ.csv',
#  'stocks _data\\CDE.csv',
#  'stocks _data\\CDEVY.csv',
#  'stocks _data\\CDK.csv',
#  'stocks _data\\CDNA.csv',
#  'stocks _data\\CDNS.csv',
#  'stocks _data\\CDR.csv',
#  'stocks _data\\CDTI.csv',
#  'stocks _data\\CDUAF.csv',
#  'stocks _data\\CDW.csv',
#  'stocks _data\\CDXS.csv',
#  'stocks _data\\CDZI.csv',
#  'stocks _data\\CEA.csv',
#  'stocks _data\\CECE.csv',
#  'stocks _data\\CEE.csv',
#  'stocks _data\\CEM.csv',
#  'stocks _data\\CEMI.csv',
#  'stocks _data\\CEN.csv',
#  'stocks _data\\CENT.csv',
#  'stocks _data\\CENX.csv',
#  'stocks _data\\CEO.csv',
#  'stocks _data\\CEQP.csv',
#  'stocks _data\\CERE.csv',
#  'stocks _data\\CERN.csv',
#  'stocks _data\\CERS.csv',
#  'stocks _data\\CESTF.csv',
#  'stocks _data\\CET.csv',
#  'stocks _data\\CEVA.csv',
#  'stocks _data\\CEVIY.csv',
#  'stocks _data\\CF.csv',
#  'stocks _data\\CFBK.csv',
#  'stocks _data\\CFEGF.csv',
#  'stocks _data\\CFFI.csv',
#  'stocks _data\\CFFN.csv',
#  'stocks _data\\CFG.csv',
#  'stocks _data\\CFNB.csv',
#  'stocks _data\\CFR.csv',
#  'stocks _data\\CFRX.csv',
#  'stocks _data\\CG.csv',
#  'stocks _data\\CGA.csv',
#  'stocks _data\\CGEMY.csv',
#  'stocks _data\\CGEN.csv',
#  'stocks _data\\CGKEY.csv',
#  'stocks _data\\CGMBF.csv',
#  'stocks _data\\CGNX.csv',
#  'stocks _data\\CGO.csv',
#  'stocks _data\\CGYV.csv',
#  'stocks _data\\CHCC.csv',
#  'stocks _data\\CHCI.csv',
#  'stocks _data\\CHCO.csv',
#  'stocks _data\\CHD.csv',
#  'stocks _data\\CHDN.csv',
#  'stocks _data\\CHDRY.csv',
#  'stocks _data\\CHE.csv',
#  'stocks _data\\CHEF.csv',
#  'stocks _data\\CHFN.csv',
#  'stocks _data\\CHH.csv',
#  'stocks _data\\CHHE.csv',
#  'stocks _data\\CHI.csv',
#  'stocks _data\\CHKGF.csv',
#  'stocks _data\\CHKP.csv',
#  'stocks _data\\CHMG.csv',
#  'stocks _data\\CHMI.csv',
#  'stocks _data\\CHNGQ.csv',
#  'stocks _data\\CHNR.csv',
#  'stocks _data\\CHPXF.csv',
#  'stocks _data\\CHRS.csv',
#  'stocks _data\\CHRW.csv',
#  'stocks _data\\CHS.csv',
#  'stocks _data\\CHSCP.csv',
#  'stocks _data\\CHSYF.csv',
#  'stocks _data\\CHT.csv',
#  'stocks _data\\CHTR.csv',
#  'stocks _data\\CHUEF.csv',
#  'stocks _data\\CHUY.csv',
#  'stocks _data\\CHW.csv',
#  'stocks _data\\CHWE.csv',
#  'stocks _data\\CHY.csv',
#  'stocks _data\\CIADY.csv',
#  'stocks _data\\CIB.csv',
#  'stocks _data\\CICHY.csv',
#  'stocks _data\\CIDM.csv',
#  'stocks _data\\CIF.csv',
#  'stocks _data\\CIHKY.csv',
#  'stocks _data\\CII.csv',
#  'stocks _data\\CIM.csv',
#  'stocks _data\\CIMDF.csv',
#  'stocks _data\\CINF.csv',
#  'stocks _data\\CINR.csv',
#  'stocks _data\\CINSF.csv',
#  'stocks _data\\CIO.csv',
#  'stocks _data\\CIOXY.csv',
#  'stocks _data\\CIR.csv',
#  'stocks _data\\CIT.csv',
#  'stocks _data\\CIVI.csv',
#  'stocks _data\\CIZN.csv',
#  'stocks _data\\CJEWF.csv',
#  'stocks _data\\CJPRF.csv',
#  'stocks _data\\CL.csv',
#  'stocks _data\\CLB.csv',
#  'stocks _data\\CLDX.csv',
#  'stocks _data\\CLFD.csv',
#  'stocks _data\\CLH.csv',
#  'stocks _data\\CLIR.csv',
#  'stocks _data\\CLMT.csv',
#  'stocks _data\\CLNE.csv',
#  'stocks _data\\CLPBY.csv',
#  'stocks _data\\CLPXY.csv',
#  'stocks _data\\CLR.csv',
#  'stocks _data\\CLRB.csv',
#  'stocks _data\\CLRI.csv',
#  'stocks _data\\CLRO.csv',
#  'stocks _data\\CLSN.csv',
#  'stocks _data\\CLVS.csv',
#  'stocks _data\\CLW.csv',
#  'stocks _data\\CLWT.csv',
#  'stocks _data\\CLX.csv',
#  'stocks _data\\CM.csv',
#  'stocks _data\\CMC.csv',
#  'stocks _data\\CMCLF.csv',
#  'stocks _data\\CMCO.csv',
#  'stocks _data\\CMCSA.csv',
#  'stocks _data\\CMCT.csv',
#  'stocks _data\\CME.csv',
#  'stocks _data\\CMG.csv',
#  'stocks _data\\CMGGF.csv',
#  'stocks _data\\CMHHF.csv',
#  'stocks _data\\CMI.csv',
#  'stocks _data\\CMLS.csv',
#  'stocks _data\\CMO.csv',
#  'stocks _data\\CMOXF.csv',
#  'stocks _data\\CMP.csv',
#  'stocks _data\\CMPGY.csv',
#  'stocks _data\\CMPNF.csv',
#  'stocks _data\\CMPR.csv',
#  'stocks _data\\CMRX.csv',
#  'stocks _data\\CMS.csv',
#  'stocks _data\\CMTDF.csv',
#  'stocks _data\\CMTL.csv',
#  'stocks _data\\CMWAY.csv',
#  'stocks _data\\CNBKA.csv',
#  'stocks _data\\CNBZ.csv',
#  'stocks _data\\CNC.csv',
#  'stocks _data\\CNCE.csv',
#  'stocks _data\\CNET.csv',
#  'stocks _data\\CNHI.csv',
#  'stocks _data\\CNI.csv',
#  'stocks _data\\CNMD.csv',
#  'stocks _data\\CNO.csv',
#  'stocks _data\\CNOB.csv',
#  'stocks _data\\CNP.csv',
#  'stocks _data\\CNPAY.csv',
#  'stocks _data\\CNQ.csv',
#  'stocks _data\\CNRAF.csv',
#  'stocks _data\\CNS.csv',
#  'stocks _data\\CNSL.csv',
#  'stocks _data\\CNTY.csv',
#  'stocks _data\\CNWT.csv',
#  'stocks _data\\CNX.csv',
#  'stocks _data\\CNXR.csv',
#  'stocks _data\\CO.csv',
#  'stocks _data\\COBZ.csv',
#  'stocks _data\\COCO.csv',
#  'stocks _data\\CODI.csv',
#  'stocks _data\\COF.csv',
#  'stocks _data\\COHR.csv',
#  'stocks _data\\COHU.csv',
#  'stocks _data\\COL.csv',
#  'stocks _data\\COLB.csv',
#  'stocks _data\\COLM.csv',
#  'stocks _data\\COMM.csv',
#  'stocks _data\\CONE.csv',
#  'stocks _data\\CONN.csv',
#  'stocks _data\\COO.csv',
#  'stocks _data\\COP.csv',
#  'stocks _data\\COR.csv',
#  'stocks _data\\CORI.csv',
#  'stocks _data\\CORR.csv',
#  'stocks _data\\CORT.csv',
#  'stocks _data\\COST.csv',
#  'stocks _data\\COTY.csv',
#  'stocks _data\\COWN.csv',
#  'stocks _data\\CP.csv',
#  'stocks _data\\CPB.csv',
#  'stocks _data\\CPCAY.csv',
#  'stocks _data\\CPE.csv',
#  'stocks _data\\CPF.csv',
#  'stocks _data\\CPFH.csv',
#  'stocks _data\\CPG.csv',
#  'stocks _data\\CPHC.csv',
#  'stocks _data\\CPICQ.csv',
#  'stocks _data\\CPIX.csv',
#  'stocks _data\\CPK.csv',
#  'stocks _data\\CPLA.csv',
#  'stocks _data\\CPLP.csv',
#  'stocks _data\\CPRT.csv',
#  'stocks _data\\CPRX.csv',
#  'stocks _data\\CPSI.csv',
#  'stocks _data\\CPSS.csv',
#  'stocks _data\\CPT.csv',
#  'stocks _data\\CPWHF.csv',
#  'stocks _data\\CPYYF.csv',
#  'stocks _data\\CRAI.csv',
#  'stocks _data\\CRARY.csv',
#  'stocks _data\\CRBJF.csv',
#  'stocks _data\\CRC.csv',
#  'stocks _data\\CRCBY.csv',
#  'stocks _data\\CRD-B.csv',
#  'stocks _data\\CREG.csv',
#  'stocks _data\\CRIS.csv',
#  'stocks _data\\CRK.csv',
#  'stocks _data\\CRL.csv',
#  'stocks _data\\CRM.csv',
#  'stocks _data\\CRMT.csv',
#  'stocks _data\\CRNT.csv',
#  'stocks _data\\CROX.csv',
#  'stocks _data\\CRRFY.csv',
#  'stocks _data\\CRS.csv',
#  'stocks _data\\CRT.csv',
#  'stocks _data\\CRTN.csv',
#  'stocks _data\\CRTO.csv',
#  'stocks _data\\CRUS.csv',
#  'stocks _data\\CRVS.csv',
#  'stocks _data\\CRWS.csv',
#  'stocks _data\\CRZBY.csv',
#  'stocks _data\\CS.csv',
#  'stocks _data\\CSASF.csv',
#  'stocks _data\\CSBK.csv',
#  'stocks _data\\CSBR.csv',
#  'stocks _data\\CSCO.csv',
#  'stocks _data\\CSGP.csv',
#  'stocks _data\\CSGS.csv',
#  'stocks _data\\CSII.csv',
#  'stocks _data\\CSIQ.csv',
#  'stocks _data\\CSL.csv',
#  'stocks _data\\CSLT.csv',
#  'stocks _data\\CSPI.csv',
#  'stocks _data\\CSQ.csv',
#  'stocks _data\\CSSI.csv',
#  'stocks _data\\CSTE.csv',
#  'stocks _data\\CSTM.csv',
#  'stocks _data\\CSU.csv',
#  'stocks _data\\CSUAY.csv',
#  'stocks _data\\CSV.csv',
#  'stocks _data\\CSWC.csv',
#  'stocks _data\\CSWYY.csv',
#  'stocks _data\\CTAS.csv',
#  'stocks _data\\CTB.csv',
#  'stocks _data\\CTBI.csv',
#  'stocks _data\\CTBK.csv',
#  'stocks _data\\CTG.csv',
#  'stocks _data\\CTHR.csv',
#  'stocks _data\\CTIB.csv',
#  'stocks _data\\CTIC.csv',
#  'stocks _data\\CTQ.csv',
#  'stocks _data\\CTR.csv',
#  'stocks _data\\CTRE.csv',
#  'stocks _data\\CTRN.csv',
#  'stocks _data\\CTRYF.csv',
#  'stocks _data\\CTSH.csv',
#  'stocks _data\\CTSO.csv',
#  'stocks _data\\CTT.csv',
#  'stocks _data\\CTXAY.csv',
#  'stocks _data\\CTXS.csv',
#  'stocks _data\\CUBA.csv',
#  'stocks _data\\CUBI.csv',
#  'stocks _data\\CUDA.csv',
#  'stocks _data\\CUK.csv',
#  'stocks _data\\CUPUF.csv',
#  'stocks _data\\CUTR.csv',
#  'stocks _data\\CUZ.csv',
#  'stocks _data\\CVA.csv',
#  'stocks _data\\CVCO.csv',
#  'stocks _data\\CVCY.csv',
#  'stocks _data\\CVE.csv',
#  'stocks _data\\CVGI.csv',
#  'stocks _data\\CVGW.csv',
#  'stocks _data\\CVLT.csv',
#  'stocks _data\\CVLY.csv',
#  'stocks _data\\CVV.csv',
#  'stocks _data\\CWAY.csv',
#  'stocks _data\\CWBC.csv',
#  'stocks _data\\CWCO.csv',
#  'stocks _data\\CWLDF.csv',
#  'stocks _data\\CWST.csv',
#  'stocks _data\\CWT.csv',
#  'stocks _data\\CXDC.csv',
#  'stocks _data\\CXE.csv',
#  'stocks _data\\CXH.csv',
#  'stocks _data\\CXP.csv',
#  'stocks _data\\CYAN.csv',
#  'stocks _data\\CYBE.csv',
#  'stocks _data\\CYBR.csv',
#  'stocks _data\\CYCC.csv',
#  'stocks _data\\CYD.csv',
#  'stocks _data\\CYH.csv',
#  'stocks _data\\CYIO.csv',
#  'stocks _data\\CYRN.csv',
#  'stocks _data\\CYS.csv',
#  'stocks _data\\CYTK.csv',
#  'stocks _data\\CYTR.csv',
#  'stocks _data\\CZNC.csv',
#  'stocks _data\\CZR.csv',
#  'stocks _data\\CZWI.csv',
#  'stocks _data\\D.csv',
#  'stocks _data\\DAHSF.csv',
#  'stocks _data\\DAIO.csv',
#  'stocks _data\\DAKT.csv',
#  'stocks _data\\DAL.csv',
#  'stocks _data\\DANOY.csv',
#  'stocks _data\\DAR.csv',
#  'stocks _data\\DASTY.csv',
#  'stocks _data\\DBL.csv',
#  'stocks _data\\DBVT.csv',
#  'stocks _data\\DCI.csv',
#  'stocks _data\\DCNSF.csv',
#  'stocks _data\\DCO.csv',
#  'stocks _data\\DCOM.csv',
#  'stocks _data\\DCT.csv',
#  'stocks _data\\DCTH.csv',
#  'stocks _data\\DD.csv',
#  'stocks _data\\DDAIF.csv',
#  'stocks _data\\DDF.csv',
#  'stocks _data\\DDS.csv',
#  'stocks _data\\DDT.csv',
#  'stocks _data\\DE.csv',
#  'stocks _data\\DECK.csv',
#  'stocks _data\\DEI.csv',
#  'stocks _data\\DEL.csv',
#  'stocks _data\\DENN.csv',
#  'stocks _data\\DEO.csv',
#  'stocks _data\\DERM.csv',
#  'stocks _data\\DEX.csv',
#  'stocks _data\\DFEL.csv',
#  'stocks _data\\DFS.csv',
#  'stocks _data\\DG.csv',
#  'stocks _data\\DGICA.csv',
#  'stocks _data\\DGII.csv',
#  'stocks _data\\DGLY.csv',
#  'stocks _data\\DGX.csv',
#  'stocks _data\\DHF.csv',
#  'stocks _data\\DHG.csv',
#  'stocks _data\\DHI.csv',
#  'stocks _data\\DHIL.csv',
#  'stocks _data\\DHT.csv',
#  'stocks _data\\DIAX.csv',
#  'stocks _data\\DIOD.csv',
#  'stocks _data\\DIS.csv',
#  'stocks _data\\DISCA.csv',
#  'stocks _data\\DISH.csv',
#  'stocks _data\\DITTF.csv',
#  'stocks _data\\DJCO.csv',
#  'stocks _data\\DK.csv',
#  'stocks _data\\DKILF.csv',
#  'stocks _data\\DKS.csv',
#  'stocks _data\\DKSHF.csv',
#  'stocks _data\\DLAKY.csv',
#  'stocks _data\\DLB.csv',
#  'stocks _data\\DLHC.csv',
#  'stocks _data\\DLMAF.csv',
#  'stocks _data\\DLNG.csv',
#  'stocks _data\\DLR.csv',
#  'stocks _data\\DLTR.csv',
#  'stocks _data\\DMB.csv',
#  'stocks _data\\DMFG.csv',
#  'stocks _data\\DMLP.csv',
#  'stocks _data\\DMO.csv',
#  'stocks _data\\DMRC.csv',
#  'stocks _data\\DNB.csv',
#  'stocks _data\\DNFGY.csv',
#  'stocks _data\\DNP.csv',
#  'stocks _data\\DNPCF.csv',
#  'stocks _data\\DNTUF.csv',
#  'stocks _data\\DOMR.csv',
#  'stocks _data\\DOOR.csv',
#  'stocks _data\\DORM.csv',
#  'stocks _data\\DOV.csv',
#  'stocks _data\\DOW.csv',
#  'stocks _data\\DOX.csv',
#  'stocks _data\\DPG.csv',
#  'stocks _data\\DPSGY.csv',
#  'stocks _data\\DPZ.csv',
#  'stocks _data\\DRE.csv',
#  'stocks _data\\DRH.csv',
#  'stocks _data\\DRI.csv',
#  'stocks _data\\DRIV.csv',
#  'stocks _data\\DRLCQ.csv',
#  'stocks _data\\DRNA.csv',
#  'stocks _data\\DRRX.csv',
#  'stocks _data\\DSDVY.csv',
#  'stocks _data\\DSEEY.csv',
#  'stocks _data\\DSGX.csv',
#  'stocks _data\\DSITF.csv',
#  'stocks _data\\DSL.csv',
#  'stocks _data\\DSM.csv',
#  'stocks _data\\DSNKY.csv',
#  'stocks _data\\DSPG.csv',
#  ...]

# %%
li_mapper = map(lambda filename:pd.read_csv(filename,index_col=None, header=0),all_files);

# %%
li = list(li_mapper)

# %%
# data contain all the stock market in the world company symbol

stocks_df =pd.concat(li,axis=0,ignore_index=True)
stocks_df
# Out:
#                 Date        Low       Open      Volume       High      Close  \
# 0         14-04-2011  20.799999  21.000000  63774200.0  22.000000  21.200001
# 1         15-04-2011  20.809999  21.219999   5891700.0  21.840000  21.360001
# 2         18-04-2011  21.110001  21.299999   5759100.0  22.950001  22.900000
# 3         19-04-2011  22.780001  23.170000  11062300.0  24.959999  24.730000
# 4         20-04-2011  23.799999  25.799999   5863400.0  25.950001  24.040001
# ...              ...        ...        ...         ...        ...        ...
# 17856275  14-12-2021  41.480000  41.939999     79000.0  41.959999  41.639999
# 17856276  15-12-2021  41.790001  41.889999     66300.0  42.220001  42.130001
# 17856277  16-12-2021  42.320000  42.490002     40900.0  42.650002  42.450001
# 17856278  17-12-2021  42.279999  42.619999     80000.0  42.619999  42.320000
# 17856279  20-12-2021  41.700001  41.820000     19795.0  42.099998  42.099998
#
#           Adjusted Close
# 0              18.751789
# 1              18.893307
# 2              20.255466
# 3              21.874142
# 4              21.263823
# ...                  ...
# 17856275       41.639999
# 17856276       42.130001
# 17856277       42.450001
# 17856278       42.320000
# 17856279       42.099998
#
# [17856280 rows x 7 columns]

# %%
def show_plot(df, fig_title):
  df.plot(x = 'Date', figsize = (15,7), linewidth = 3, title = fig_title)
  plt.grid()
  plt.show()

# %%
# Sort the stock data by date
stocks_df = stocks_df.sort_values(by = ['Date'])
stocks_df
# Out:
#                 Date         Low        Open     Volume        High  \
# 9285377   01-02-1971    0.415638    0.419753  2344950.0    0.419753
# 7204858   01-02-1971   15.535373   15.559273   642244.0   15.678776
# 2655324   01-02-1971   12.785500   12.785500    76868.0   12.926000
# 9788663   01-02-1971    6.210938    6.210938   568000.0    6.250000
# 9898276   01-02-1971    0.549479    0.549479  6614400.0    0.558594
# ...              ...         ...         ...        ...         ...
# 15907784  31-12-2020   33.529999   33.529999    33100.0   35.200001
# 4471936   31-12-2020   23.650000   24.280001   874700.0   24.280001
# 15258016  31-12-2020  182.380005  182.380005     3000.0  189.910004
# 3284096   31-12-2020   17.940001   18.070000   106700.0   18.299999
# 10920910  31-12-2020   13.610000   13.730000  2553100.0   13.860000
#
#                Close  Adjusted Close
# 9285377     0.419753        0.192801
# 7204858    15.642925        3.818194
# 2655324    12.926000        0.509122
# 9788663     6.226563        1.327072
# 9898276     0.557292        0.014132
# ...              ...             ...
# 15907784   34.680000       34.680000
# 4471936    24.010000       24.010000
# 15258016  186.860001      186.860001
# 3284096    18.180000       18.180000
# 10920910   13.730000       13.671474
#
# [17856280 rows x 7 columns]

# %%
# Print out the number of stocks
print('Total Number of stocks : {}'.format(len(stocks_df.columns[1:])))
# Out:
# Total Number of stocks : 6

# %%
# Print the name of stocks
print('Stocks under consideration are:')

for i in stocks_df.columns[1:]:
  print(i)
# Out:
# Stocks under consideration are:
# Low
# Open
# Volume
# High
# Close
# Adjusted Close

# %%
# Check if data contains any null values
stocks_df.isnull().sum()
# Out:
# Date                   0
# Low               188821
# Open              188821
# Volume            188821
# High              188821
# Close             188821
# Adjusted Close    188821
# dtype: int64

# %%
# Getting dataframe info
stocks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17856280 entries, 9285377 to 10920910
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Date            object
#  1   Low             float64
#  2   Open            float64
#  3   Volume          float64
#  4   High            float64
#  5   Close           float64
#  6   Adjusted Close  float64
# dtypes: float64(6), object(1)
# memory usage: 1.1+ GB

# %%
def show_plot(df, fig_title):
  df.plot(x = 'Date', figsize = (15,7), linewidth = 3, title = fig_title)
  plt.grid()
  plt.show()

# %%
# Let's define a function to calculate stocks daily returns (for all stocks) 
def daily_return(df):
  df_daily_return = stocks_df.copy()

  # Loop through each stock (while ignoring time columns with index 0)
  for i in df.columns[1:]:
    
    # Loop through each row belonging to the stock
    for j in range(1, len(df)):

      # Calculate the percentage of change from the previous day
      df_daily_return[i][j] = ((df[i][j]- df[i][j-1])/df[i][j-1]) * 100
    
    # set the value of first row to zero since the previous value is not available
    df_daily_return[i][0] = 0
  
  return df_daily_return

# %%
# Get the daily returns 
stocks_daily_return = daily_return(stocks_df)

# %%
stocks_daily_return

# %%
# Group all data returns together in a list
# Make a copy of the daily returns dataframe
df_hist = stocks_daily_return.copy()

# Drop the date
df_hist = df_hist.drop(columns = ['Date'])

data = []

# Loop through every column
for i in df_hist.columns:
  data.append(stocks_daily_return[i].values)
data

# %%
fig = ff.create_distplot(data, df_hist.columns)
fig.show()

# %%
import pandas as pd
import plotly.express as px
from copy import copy
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
import plotly.figure_factory as ff
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
# Read stock prices data
stock_price_df = pd.read_csv('1.1 stock.csv')
stock_price_df

# %%
# Read the stocks volume data
stock_vol_df = pd.read_csv('stock_volume.csv')
stock_vol_df

# %%
# Sort the data based on Date
stock_price_df = stock_price_df.sort_values(by = ['Date'])
stock_price_df

# %%
# Sort the data based on Date
stock_vol_df = stock_vol_df.sort_values(by = ['Date'])
stock_vol_df

# %%
# Check if Null values exist in stock prices data
stock_price_df.isnull().sum()

# %%
# Check if Null values exist in stocks volume data
stock_vol_df.isnull().sum()

# %%
# Get stock prices dataframe info
stock_price_df.info()

# %%
# Get stock volume dataframe info
stock_vol_df.info()

# %%
stock_vol_df.describe()

# %%
## prepare the data 
# Function to concatenate the date, stock price, and volume in one dataframe
def individual_stock(price_df, vol_df, name):
    return pd.DataFrame({'Date': price_df['Date'], 'Close': price_df[name], 'Volume': vol_df[name]})

# %%
# Function to return the input/output (target) data for AI/ML Model
# Note that our goal is to predict the future stock price 
# Target stock price today will be tomorrow's price 
def trading_window(data):
  
  # 1 day window 
  n = 1

  # Create a column containing the prices for the next 1 days
  data['Target'] = data[['Close']].shift(-n)
  
  # return the new dataset 
  return data

# %%
# Let's test the functions and get individual stock prices and volumes for AAPL
price_volume_df = individual_stock(stock_price_df, stock_vol_df, 'AAPL')
price_volume_df

# %%
price_volume_target_df = trading_window(price_volume_df)
price_volume_target_df

# %%
# Remove the last row as it will be a null value
price_volume_target_df = price_volume_target_df[:-1]
price_volume_target_df

# %%
# Scale the data
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
price_volume_target_scaled_df = sc.fit_transform(price_volume_target_df.drop(columns = ['Date']))

# %%
price_volume_target_scaled_df

# %%
price_volume_target_scaled_df.shape

# %%
# Creating Feature and Target
X = price_volume_target_scaled_df[:,:2]
y = price_volume_target_scaled_df[:,2:]

# %%
# Converting dataframe to arrays
# X = np.asarray(X)
# y = np.asarray(y)
X.shape, y.shape

# %%
split = int(0.65 * len(X))
X_train = X[:split]
y_train = y[:split]
X_test = X[split:]
y_test = y[split:]

# %%
X_train.shape, y_train.shape

# %%
X_test.shape, y_test.shape

# %%
# Define a data plotting function
def show_plot(data, title):
  plt.figure(figsize = (13, 5))
  plt.plot(data, linewidth = 3)
  plt.title(title)
  plt.grid()

show_plot(X_train, 'Training Data')
show_plot(X_test, 'Testing Data')

# %%
from sklearn.linear_model import Ridge
# Note that Ridge regression performs linear least squares with L2 regularization.
# Create and train the Ridge Linear Regression  Model
regression_model = Ridge()
regression_model.fit(X_train, y_train)

# %%
# Test the model and calculate its accuracy 
lr_accuracy = regression_model.score(X_test, y_test)
print("Linear Regression Score: ", lr_accuracy)

# %%
# Make Prediction
predicted_prices = regression_model.predict(X)
predicted_prices

# %%
# Append the predicted values into a list
Predicted = []
for i in predicted_prices:
  Predicted.append(i[0])

# %%
len(Predicted)

# %%
# Append the close values to the list
close = []
for i in price_volume_target_scaled_df:
  close.append(i[0])

# %%
# Create a dataframe based on the dates in the individual stock data
df_predicted = price_volume_target_df[['Date']]
df_predicted

# %%
# Add the close values to the dataframe
df_predicted['Close'] = close
df_predicted

# %%
# Add the predicted values to the dataframe
df_predicted['Prediction'] = Predicted
df_predicted

# %%
#train an lstm time series model
# Let's test the functions and get individual stock prices and volumes for AAPL
price_volume_df = individual_stock(stock_price_df, stock_vol_df, 'sp500')
price_volume_df

# %%
# Get the close and volume data as training data (Input)
training_data = price_volume_df.iloc[:, 1:3].values
training_data

# %%
# Normalize the data
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_data)

# %%
# Create the training and testing data, training data contains present day and previous day values
X = []
y = []
for i in range(1, len(price_volume_df)):
    X.append(training_set_scaled [i-1:i, 0])
    y.append(training_set_scaled [i, 0])

# %%
X

# %%
# Convert the data into array format
X = np.asarray(X)
y = np.asarray(y)

# %%
# Split the data
split = int(0.7 * len(X))
X_train = X[:split]
y_train = y[:split]
X_test = X[split:]
y_test = y[split:]

# %%
# Reshape the 1D arrays to 3D arrays to feed in the model
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
X_train.shape, X_test.shape

# %%
# Tensorflow
import tensorflow as tf
from tensorflow.keras.preprocessing.text import one_hot,Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Embedding, Input, LSTM, Conv1D, MaxPool1D, Bidirectional, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical

# %%
# Create the model
inputs = keras.layers.Input(shape=(X_train.shape[1], X_train.shape[2]))
x = keras.layers.LSTM(150, return_sequences= True)(inputs)
x = keras.layers.Dropout(0.3)(x)
x = keras.layers.LSTM(150, return_sequences=True)(x)
x = keras.layers.Dropout(0.3)(x)
x = keras.layers.LSTM(150)(x)
outputs = keras.layers.Dense(1, activation='linear')(x)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss="mse")
model.summary()

# %%
# Trai the model
history = model.fit(
    X_train, y_train,
    epochs = 20,
    batch_size = 32,
    validation_split = 0.2
)

# %%
# Make prediction
predicted = model.predict(X)

# %%
test_predicted

# %%
df_predicted = price_volume_df[1:][['Date']]
df_predicted

# %%
df_predicted['predictions'] = test_predicted

# %%
df_predicted

# %%
# Plot the data
close = []
for i in training_set_scaled:
  close.append(i[0])

# %%
df_predicted['Close'] = close[1:]

# %%
df_predicted

# %%
# Plot the data
interactive_plot(df_predicted, "Original Vs Prediction")
